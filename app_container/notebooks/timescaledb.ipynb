# %%
import psycopg2

# %%
CONNECTION = "postgres://tsuma.thomas@cropnuts.com:TobiramaNaruto13!@host:port/dbname"

# %%
01H7ET3B6AD1P3MDD6DYHG67HF
PavMqIU24HbnFFfTTsPeNAVX6caBE4g4viFvzQFJXSNO3dlLRX0llqLTR2PId81A

# %%
import psycopg2
import pandas as pd

# %%
from sqlalchemy import MetaData, Table, Column, Integer, TIMESTAMP, Float, String

metadata = MetaData()
table_name = "your_table_name"
hypertable = Table(
    table_name,
    metadata,
    Column("time",  TIMESTAMP, nullable=False),
    Column("sensor_id", Integer, nullable=False),
    Column("value", Float),
    Column("tag", String)
)

# %%
import sqlalchemy
dir(sqlalchemy)
# Out:
# ['ARRAY',
#  'AdaptedConnection',
#  'Alias',
#  'AliasedReturnsRows',
#  'Any',
#  'AssertionPool',
#  'AsyncAdaptedQueuePool',
#  'BIGINT',
#  'BINARY',
#  'BLANK_SCHEMA',
#  'BLOB',
#  'BOOLEAN',
#  'BaseDDLElement',
#  'BaseRow',
#  'BigInteger',
#  'BinaryExpression',
#  'BindParameter',
#  'BindTyping',
#  'Boolean',
#  'BooleanClauseList',
#  'CHAR',
#  'CLOB',
#  'CTE',
#  'CacheKey',
#  'Case',
#  'Cast',
#  'CheckConstraint',
#  'ChunkedIteratorResult',
#  'ClauseElement',
#  'ClauseList',
#  'CollectionAggregate',
#  'Column',
#  'ColumnClause',
#  'ColumnCollection',
#  'ColumnDefault',
#  'ColumnElement',
#  'ColumnOperators',
#  'Compiled',
#  'CompoundSelect',
#  'Computed',
#  'Connection',
#  'Constraint',
#  'CreateEnginePlugin',
#  'CursorResult',
#  'DATE',
#  'DATETIME',
#  'DDL',
#  'DDLElement',
#  'DECIMAL',
#  'DOUBLE',
#  'DOUBLE_PRECISION',
#  'Date',
#  'DateTime',
#  'DefaultClause',
#  'Delete',
#  'Dialect',
#  'Double',
#  'Engine',
#  'Enum',
# ...

# %%
from sqlalchemy.sql import text

insert_query = text(f"INSERT INTO {table_name} (time, sensor_id, value, tag) VALUES (:time, :sensor_id, :value, :tag)")

with engine.connect() as connection:
    connection.execute(
        insert_query,
        time="2023-08-01 12:00:00",
        sensor_id=1,
        value=25.5,
        tag="temperature"
    )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File C:\Python310\lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File C:\Python310\lib\site-packages\sqlalchemy\engine\base.py:3269, in Engine.raw_connection(self)
#    3248 """Return a "raw" DBAPI connection from the connection pool.
#    3249
#    3250 The returned object is a proxied version of the DBAPI
#    (...)
#    3267
#    3268 """
# -> 3269 return self.pool.connect()
#
# File C:\Python310\lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
# ...

# %%
connection = psycopg2.connect(
        user="postgres",
          password="Tobirama13",
          host="13.37.61.181",
          port="5432",
          database="postgres")
cursor = connection.cursor()

# %%
create_table_query = """
    CREATE TABLE daily_recurring_revenue (
        id SERIAL PRIMARY KEY,
        amount NUMERIC,
        time TIMESTAMP
    )
    """
cursor.execute(create_table_query)
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Input In [83], in <cell line: 8>()
#       1 create_table_query = """
#       2     CREATE TABLE daily_recurring_revenue (
#       3         id SERIAL PRIMARY KEY,
#    (...)
#       6     )
#       7     """
# ----> 8 cursor.execute(create_table_query)
#
# DuplicateTable: relation "daily_recurring_revenue" already exists

# %%
connection.commit()

# %%
insert_records_query = """
INSERT INTO daily_recurring_revenue (amount, time)
VALUES
    (100.50, '2023-08-05 12:00:00'),
    (75.25, '2023-08-05 14:30:00'),
    (200.00, '2023-08-06 10:00:00')
"""

cursor.execute(insert_records_query)

# %%
retrieve_records_query = """
 SELECT * FROM daily_recurring_revenue
"""
res = cursor.execute(retrieve_records_query)

# %%
df = pd.read_sql("SELECT * FROM daily_recurring_revenue", con=connection)
# Out:
# C:\Users\Tsuma Thomas\AppData\Local\Temp\ipykernel_18240\47880673.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM daily_recurring_revenue", con=connection)

# %%
df
# Out:
#    id  amount                time
# 0  18  100.50                 NaT
# 1  19   75.25                 NaT
# 2  20  200.00                 NaT
# 3  21  100.50 2023-08-05 12:00:00
# 4  22   75.25 2023-08-05 14:30:00
# 5  23  200.00 2023-08-06 10:00:00

# %%
create_hypertable_query = """
 SELECT create_hypertable('daily_recurring_revenue','time')
"""
res = cursor.execute(create_hypertable_query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [108], in <cell line: 4>()
#       1 create_hypertable_query = """
#       2  SELECT create_hypertable('daily_recurring_revenue','time')
#       3 """
# ----> 4 res = cursor.execute(create_hypertable_query)
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
